# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('datatugas.csv')
data.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    int64
#  1   y       300 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB

# %%
data.describe()
# Out:
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837

# %%
plt.figure(figsize=(10,5))
sns.pairplot(data,x_vars=['x'],y_vars=['y'],height=8,kind='scatter')
plt.xlabel('data x')
plt.ylabel('data y')
plt.title('Data Linear Regression')
plt.show()

# %%
X = data['x']
X.head()
# Out:
# 0    77
# 1    21
# 2    22
# 3    20
# 4    36
# Name: x, dtype: int64

# %%
y = data['y']
y.head()
# Out:
# 0    79.775152
# 1    23.177279
# 2    25.609262
# 3    17.857388
# 4    41.849864
# Name: y, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=100)

# %%
X_train = X_train[:,np.newaxis]
X_test = X_test[:,np.newaxis]
# Out:
# C:\Users\ALEXAL~1\AppData\Local\Temp/ipykernel_11948/2733214152.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_train = X_train[:,np.newaxis]
# C:\Users\ALEXAL~1\AppData\Local\Temp/ipykernel_11948/2733214152.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_test = X_test[:,np.newaxis]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
plt.scatter(X_test,y_test,color='r')
plt.plot(X_test,y_pred,color='b',linestyle='-')
plt.xlabel('data x')
plt.ylabel('data y')
plt.title('Data Linear Regression')
plt.show()
